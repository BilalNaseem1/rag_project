# %%
from IPython.display import clear_output
# !pip install langchain
# !pip install youtube-transcript-api
# !pip install pytube
# !pip install openai
clear_output()

# %%
import pandas as pd
from googleapiclient.discovery import build
from langchain.document_loaders import YoutubeLoader

# %%
df = pd.read_csv('benjamin_cowen_290_transcripts.csv')
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#            Author                              title  \
# 0  Benjamin Cowen                S&amp;P 500 Outlook
# 1  Benjamin Cowen  Bitcoin: Bull Market Support Band
# 2  Benjamin Cowen                  Bitcoin Dominance
# 3  Benjamin Cowen   The 2024 Bitcoin Halving (LIVE!)
# 4  Benjamin Cowen    Bitcoin: The Halving Approaches
#
#                                            url  \
# 0  https://www.youtube.com/watch?v=urgVQ-ltTf8
# 1  https://www.youtube.com/watch?v=wfzsVDeBu0o
# 2  https://www.youtube.com/watch?v=OrEdDZ94Od0
# 3  https://www.youtube.com/watch?v=fAuXfvZ5W9o
# 4  https://www.youtube.com/watch?v=QhJFtaXaYxE
#
#                                           Transcript           Type  \
# 0  hey everyone and thanks for jumping back into ...  Youtube video
# 1  hey everyone and thanks for jumping back into ...  Youtube video
# 2  hey everyone and thanks for jumping back into ...  Youtube video
# 3  hey everyone and thanks for jumping back into ...  Youtube video
# 4  hey everyone and thanks for jumping back into ...  Youtube video
#
#           Publish_Date
# 0  2024-04-23 00:00:00
# 1  2024-04-22 00:00:00
# 2  2024-04-21 00:00:00
# 3  2024-04-19 00:00:00
# 4  2024-04-19 00:00:00

# %%
api_key = "AIzaSyCIVHAyo1QU194HManplOS0JZteERJyvvY"

youtube = build("youtube", "v3", developerKey=api_key)

# %%
to_replace = {
    'hey everyone and thanks for jumping back into the cryptoverse': '',
    '[Music]': '',
    '\n': ' ',
    '[\xa0__\xa0]': ''
}

def replace_words(row):
    for old_word, new_word in to_replace.items():
        row = row.replace(old_word, new_word)
    return row

df['Transcript'] = df['Transcript'].apply(replace_words)

# hey everyone and thanks for jumping back into the cryptoverse
# [Music]
# \n
# [\xa0__\xa0]

# %%
df.head(5)
# Out:
#            Author                              title  \
# 0  Benjamin Cowen                S&amp;P 500 Outlook
# 1  Benjamin Cowen  Bitcoin: Bull Market Support Band
# 2  Benjamin Cowen                  Bitcoin Dominance
# 3  Benjamin Cowen   The 2024 Bitcoin Halving (LIVE!)
# 4  Benjamin Cowen    Bitcoin: The Halving Approaches
#
#                                            url  \
# 0  https://www.youtube.com/watch?v=urgVQ-ltTf8
# 1  https://www.youtube.com/watch?v=wfzsVDeBu0o
# 2  https://www.youtube.com/watch?v=OrEdDZ94Od0
# 3  https://www.youtube.com/watch?v=fAuXfvZ5W9o
# 4  https://www.youtube.com/watch?v=QhJFtaXaYxE
#
#                                           Transcript           Type  \
# 0  hey everyone and thanks for jumping back into ...  Youtube video
# 1   today we're going to talk about Bitcoin and w...  Youtube video
# 2   today we're going to talk about Bitcoin but m...  Youtube video
# 3   we are now at the or about to be at the 2024 ...  Youtube video
# 4  hey everyone and thanks for jumping back into ...  Youtube video
#
#           Publish_Date
# 0  2024-04-23 00:00:00
# 1  2024-04-22 00:00:00
# 2  2024-04-21 00:00:00
# 3  2024-04-19 00:00:00
# 4  2024-04-19 00:00:00

# %%
df.shape
# Out:
# (291, 6)

# %%
# # loading video transcripts

# loader = YoutubeLoader.from_youtube_url("https://www.youtube.com/watch?v=8xRz8ra9mdI", add_video_info=True)
# result = loader.load()

# result
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
import pandas as pd
# from your_module import RecursiveCharacterTextSplitter  # Replace 'your_module' with the actual module name

def chunk_transcript(transcript, max_length, overlap):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=max_length, chunk_overlap=overlap)
    chunks = text_splitter.create_documents([transcript])
    return chunks

subset_latest_videos = df  # Assuming your original DataFrame is named 'df'
new_rows = []
for idx, row in subset_latest_videos.iterrows():
    transcript = row['Transcript']
    chunks = chunk_transcript(transcript, max_length=4000, overlap=10)
    for i, chunk in enumerate(chunks):
        new_row = row.copy()
        new_row['Transcript'] = chunk
        new_row['ChunkIndex'] = i
        new_rows.append(new_row)

new_df = pd.DataFrame(new_rows)
new_df
# Out:
#              Author                                   title  \
# 0    Benjamin Cowen                     S&amp;P 500 Outlook
# 0    Benjamin Cowen                     S&amp;P 500 Outlook
# 0    Benjamin Cowen                     S&amp;P 500 Outlook
# 0    Benjamin Cowen                     S&amp;P 500 Outlook
# 0    Benjamin Cowen                     S&amp;P 500 Outlook
# ..              ...                                     ...
# 290  Benjamin Cowen  Can A Bitcoin-Only Rally Happen Again?
# 290  Benjamin Cowen  Can A Bitcoin-Only Rally Happen Again?
# 290  Benjamin Cowen  Can A Bitcoin-Only Rally Happen Again?
# 290  Benjamin Cowen  Can A Bitcoin-Only Rally Happen Again?
# 290  Benjamin Cowen  Can A Bitcoin-Only Rally Happen Again?
#
#                                              url  \
# 0    https://www.youtube.com/watch?v=urgVQ-ltTf8
# 0    https://www.youtube.com/watch?v=urgVQ-ltTf8
# 0    https://www.youtube.com/watch?v=urgVQ-ltTf8
# 0    https://www.youtube.com/watch?v=urgVQ-ltTf8
# 0    https://www.youtube.com/watch?v=urgVQ-ltTf8
# ..                                           ...
# 290  https://www.youtube.com/watch?v=ipOtDV0hDyA
# 290  https://www.youtube.com/watch?v=ipOtDV0hDyA
# 290  https://www.youtube.com/watch?v=ipOtDV0hDyA
# 290  https://www.youtube.com/watch?v=ipOtDV0hDyA
# 290  https://www.youtube.com/watch?v=ipOtDV0hDyA
#
#                                             Transcript           Type  \
# 0    page_content="hey everyone and thanks for jump...  Youtube video
# 0    page_content="of Prior election years and on a...  Youtube video
# 0    page_content="on that especially with the hyg ...  Youtube video
# 0    page_content="you look at the S&P 500 you will...  Youtube video
# 0    page_content="it does get tested whether we ho...  Youtube video
# ..                                                 ...            ...
# 290  page_content="buy those because they're giving...  Youtube video
# 290  page_content="is that a lot of the new retail ...  Youtube video
# 290  page_content="a a very prolonged crypto winter...  Youtube video
# 290  page_content="off here and goes something like...  Youtube video
# 290  page_content="premium list into the cryptovers...  Youtube video
#
#             Publish_Date  ChunkIndex
# 0    2024-04-23 00:00:00           0
# 0    2024-04-23 00:00:00           1
# 0    2024-04-23 00:00:00           2
# 0    2024-04-23 00:00:00           3
# 0    2024-04-23 00:00:00           4
# ..                   ...         ...
# 290  2022-01-19 00:00:00           1
# 290  2022-01-19 00:00:00           2
# 290  2022-01-19 00:00:00           3
# 290  2022-01-19 00:00:00           4
# 290  2022-01-19 00:00:00           5
#
# [1746 rows x 7 columns]

# %%
new_df['Transcript'] = new_df['Transcript'].astype(str)

# %%
to_replace = {
    'page_content="': '',
    '"': '',
    '\n': ' ',
    '[\xa0__\xa0]': ''
}

def replace_words(row):
    for old_word, new_word in to_replace.items():
        row = row.replace(old_word, new_word)
    return row

new_df['Transcript'] = new_df['Transcript'].apply(replace_words)

# hey everyone and thanks for jumping back into the cryptoverse
# [Music]
# \n
# [\xa0__\xa0]

# %%
# from openai import  OpenAI
new_df = new_df.reset_index(drop=True)
# client = OpenAI(api_key="sk-proj-sGU6xSsCaFHhQVyOl2WHT3BlbkFJGw3kWSnMrJoDUsHsp6tJ")

# %%
# %pip install llama-index-embeddings-together

# %%
# !pip install llama-index
clear_output()

# %%
import time
from tqdm import tqdm
from openai import OpenAI
from llama_index.embeddings.together import TogetherEmbedding




# EMBEDDING_ENGINE = "text-embedding-3-small"
embed_model = TogetherEmbedding(
    model_name="togethercomputer/m2-bert-80M-8k-retrieval", api_key="4319faab0bb21ef24fa3d3702a0085b664ba9de24f1075e542f3efb593411448"
)
new_df.reset_index(drop=True, inplace=True)

# Define a function to embed text with sleep after each call
def embed_text(text):
    # result = client.embeddings.create(input=text, model=EMBEDDING_ENGINE).data[0].embedding
    result = embed_model.get_text_embedding(text)
    time.sleep(0.1)  # Sleep for 5 seconds after each API call
    return result

# Initialize an empty list to store embeddings
embeddings = []

# Apply the function to each element of the DataFrame with tqdm progress bar
for index, row in tqdm(new_df.iterrows(), total=new_df.shape[0], desc="Embedding texts"):
    embedding = embed_text(row['Transcript'])
    embeddings.append(embedding)

# Assign the computed embeddings back to the DataFrame
new_df['embeddings'] = embeddings

# %%
len(embeddings)
# Out:
# 1746

# %%
new_df
# Out:
#               Author                                   title  \
# 0     Benjamin Cowen                     S&amp;P 500 Outlook
# 1     Benjamin Cowen                     S&amp;P 500 Outlook
# 2     Benjamin Cowen                     S&amp;P 500 Outlook
# 3     Benjamin Cowen                     S&amp;P 500 Outlook
# 4     Benjamin Cowen                     S&amp;P 500 Outlook
# ...              ...                                     ...
# 1741  Benjamin Cowen  Can A Bitcoin-Only Rally Happen Again?
# 1742  Benjamin Cowen  Can A Bitcoin-Only Rally Happen Again?
# 1743  Benjamin Cowen  Can A Bitcoin-Only Rally Happen Again?
# 1744  Benjamin Cowen  Can A Bitcoin-Only Rally Happen Again?
# 1745  Benjamin Cowen  Can A Bitcoin-Only Rally Happen Again?
#
#                                               url  \
# 0     https://www.youtube.com/watch?v=urgVQ-ltTf8
# 1     https://www.youtube.com/watch?v=urgVQ-ltTf8
# 2     https://www.youtube.com/watch?v=urgVQ-ltTf8
# 3     https://www.youtube.com/watch?v=urgVQ-ltTf8
# 4     https://www.youtube.com/watch?v=urgVQ-ltTf8
# ...                                           ...
# 1741  https://www.youtube.com/watch?v=ipOtDV0hDyA
# 1742  https://www.youtube.com/watch?v=ipOtDV0hDyA
# 1743  https://www.youtube.com/watch?v=ipOtDV0hDyA
# 1744  https://www.youtube.com/watch?v=ipOtDV0hDyA
# 1745  https://www.youtube.com/watch?v=ipOtDV0hDyA
#
#                                              Transcript           Type  \
# 0     hey everyone and thanks for jumping back into ...  Youtube video
# 1     of Prior election years and on average you kno...  Youtube video
# 2     on that especially with the hyg minus the vix ...  Youtube video
# 3     you look at the S&P 500 you will find a trend ...  Youtube video
# 4     it does get tested whether we hold it or not w...  Youtube video
# ...                                                 ...            ...
# 1741  buy those because they're giving they're givin...  Youtube video
# 1742  is that a lot of the new retail investors don'...  Youtube video
# 1743  a a very prolonged crypto winter that's going ...  Youtube video
# 1744  off here and goes something like that where it...  Youtube video
# 1745  premium list into the cryptoverse.com thank yo...  Youtube video
#
#              Publish_Date  ChunkIndex  \
# 0     2024-04-23 00:00:00           0
# 1     2024-04-23 00:00:00           1
# 2     2024-04-23 00:00:00           2
# 3     2024-04-23 00:00:00           3
# 4     2024-04-23 00:00:00           4
# ...                   ...         ...
# 1741  2022-01-19 00:00:00           1
# 1742  2022-01-19 00:00:00           2
# 1743  2022-01-19 00:00:00           3
# 1744  2022-01-19 00:00:00           4
# 1745  2022-01-19 00:00:00           5
#
#                                              embeddings
# 0     [-0.08819421, 0.009531257, 0.12350554, -0.0075...
# 1     [-0.1411094, 0.14431366, 0.23017558, 0.2302184...
# 2     [-0.22797187, 0.2704904, 0.30914462, 0.1717245...
# 3     [-0.16286558, 0.28571445, 0.012381215, 0.15279...
# 4     [0.1636779, 0.14160177, 0.18465102, 0.02442337...
# ...                                                 ...
# 1741  [0.022315634, 0.06783005, 0.18800762, 0.109727...
# 1742  [-0.09296543, -0.10450434, -0.1377965, 0.02972...
# 1743  [-0.1831777, 0.07432108, 0.053475693, 0.078203...
# 1744  [-0.16576551, 0.031720664, -0.09333118, 0.1837...
# 1745  [0.025560046, -0.06570797, -0.045289505, 0.076...
#
# [1746 rows x 8 columns]

# %%
new_df.to_csv('benj_cowen_290_w_bert80m_embeddings.csv', index=False)

# %%
MAX_TOKENS = 5000
import tiktoken

tokenizer = tiktoken.get_encoding("cl100k_base")

new_df["tokens"] = new_df.Transcript.apply(lambda x: len(tokenizer.encode(x)))

new_df.head()
# Out:
#            Author                title  \
# 0  Benjamin Cowen  S&amp;P 500 Outlook
# 1  Benjamin Cowen  S&amp;P 500 Outlook
# 2  Benjamin Cowen  S&amp;P 500 Outlook
# 3  Benjamin Cowen  S&amp;P 500 Outlook
# 4  Benjamin Cowen  S&amp;P 500 Outlook
#
#                                            url  \
# 0  https://www.youtube.com/watch?v=urgVQ-ltTf8
# 1  https://www.youtube.com/watch?v=urgVQ-ltTf8
# 2  https://www.youtube.com/watch?v=urgVQ-ltTf8
# 3  https://www.youtube.com/watch?v=urgVQ-ltTf8
# 4  https://www.youtube.com/watch?v=urgVQ-ltTf8
#
#                                           Transcript           Type  \
# 0  hey everyone and thanks for jumping back into ...  Youtube video
# 1  of Prior election years and on average you kno...  Youtube video
# 2  on that especially with the hyg minus the vix ...  Youtube video
# 3  you look at the S&P 500 you will find a trend ...  Youtube video
# 4  it does get tested whether we hold it or not w...  Youtube video
#
#           Publish_Date  ChunkIndex  \
# 0  2024-04-23 00:00:00           0
# 1  2024-04-23 00:00:00           1
# 2  2024-04-23 00:00:00           2
# 3  2024-04-23 00:00:00           3
# 4  2024-04-23 00:00:00           4
#
#                                           embeddings  tokens
# 0  [-0.08819421, 0.009531257, 0.12350554, -0.0075...     890
# 1  [-0.1411094, 0.14431366, 0.23017558, 0.2302184...     917
# 2  [-0.22797187, 0.2704904, 0.30914462, 0.1717245...     880
# 3  [-0.16286558, 0.28571445, 0.012381215, 0.15279...     888
# 4  [0.1636779, 0.14160177, 0.18465102, 0.02442337...     910

# %%
max(new_df['tokens'])
# Out:
# 963

# %% [markdown]
# ### Pinecone

# %%
df = pd.read_csv('benj_cowen_290_w_bert80m_embeddings.csv')
df.head()
# Out:
#            Author                title  \
# 0  Benjamin Cowen  S&amp;P 500 Outlook
# 1  Benjamin Cowen  S&amp;P 500 Outlook
# 2  Benjamin Cowen  S&amp;P 500 Outlook
# 3  Benjamin Cowen  S&amp;P 500 Outlook
# 4  Benjamin Cowen  S&amp;P 500 Outlook
#
#                                            url  \
# 0  https://www.youtube.com/watch?v=urgVQ-ltTf8
# 1  https://www.youtube.com/watch?v=urgVQ-ltTf8
# 2  https://www.youtube.com/watch?v=urgVQ-ltTf8
# 3  https://www.youtube.com/watch?v=urgVQ-ltTf8
# 4  https://www.youtube.com/watch?v=urgVQ-ltTf8
#
#                                           Transcript           Type  \
# 0  hey everyone and thanks for jumping back into ...  Youtube video
# 1  of Prior election years and on average you kno...  Youtube video
# 2  on that especially with the hyg minus the vix ...  Youtube video
# 3  you look at the S&P 500 you will find a trend ...  Youtube video
# 4  it does get tested whether we hold it or not w...  Youtube video
#
#           Publish_Date  ChunkIndex  \
# 0  2024-04-23 00:00:00           0
# 1  2024-04-23 00:00:00           1
# 2  2024-04-23 00:00:00           2
# 3  2024-04-23 00:00:00           3
# 4  2024-04-23 00:00:00           4
#
#                                           embeddings
# 0  [-0.08819421, 0.009531257, 0.12350554, -0.0075...
# 1  [-0.1411094, 0.14431366, 0.23017558, 0.2302184...
# 2  [-0.22797187, 0.2704904, 0.30914462, 0.1717245...
# 3  [-0.16286558, 0.28571445, 0.012381215, 0.15279...
# 4  [0.1636779, 0.14160177, 0.18465102, 0.02442337...

# %%
import numpy as np
df['embeddings'] = df.embeddings.apply(eval).apply(np.array)
embedding_dimension = len(df.iloc[0]["embeddings"])
embedding_dimension
# Out:
# 768

# %%
from pinecone import ServerlessSpec, PodSpec, Pinecone
spec = ServerlessSpec(cloud='aws', region='us-west-2')

api_key = "805b93a4-7e60-47df-9184-537be20493ce"
# configuring client
pc = Pinecone(api_key=api_key)


import time

index_name = 'benjamin-cowen-youtube'

dimensions = embedding_dimension
if index_name not in pc.list_indexes().names():
    pc.create_index(
        name= index_name,
        dimension = dimensions,
        metric = "cosine",
        spec=spec
        )

# wait for index to be ready before connecting - cell not finish
while not pc.describe_index(index_name).status['ready']:
    time.sleep(1)

# %%
pc.list_indexes()
# Out:
# {'indexes': [{'dimension': 1536,
#               'host': 'youtube-chatbot-agent-x3amlsu.svc.apw5-4e34-81fa.pinecone.io',
#               'metric': 'cosine',
#               'name': 'youtube-chatbot-agent',
#               'spec': {'serverless': {'cloud': 'aws', 'region': 'us-west-2'}},
#               'status': {'ready': True, 'state': 'Ready'}},
#              {'dimension': 1536,
#               'host': 'sample-movies-x3amlsu.svc.apw5-4e34-81fa.pinecone.io',
#               'metric': 'cosine',
#               'name': 'sample-movies',
#               'spec': {'serverless': {'cloud': 'aws', 'region': 'us-west-2'}},
#               'status': {'ready': True, 'state': 'Ready'}},
#              {'dimension': 768,
#               'host': 'benjamin-cowen-youtube-x3amlsu.svc.apw5-4e34-81fa.pinecone.io',
#               'metric': 'cosine',
#               'name': 'benjamin-cowen-youtube',
#               'spec': {'serverless': {'cloud': 'aws', 'region': 'us-west-2'}},
#               'status': {'ready': True, 'state': 'Ready'}}]}

# %%
from uuid import uuid4
import numpy as np
#####
# UPSERTING DATA
index = pc.Index(index_name)

# Generate Unique IDs
df["id"] = [str(uuid4()) for _ in range(len(df))]

batch_size = 100  # Recommended batch size from the documentation

# Convert DataFrame to list of dictionaries
items = df.to_dict(orient="records")

# Iterate over the data in batches
for i in range(0, len(items), batch_size):
    batch = items[i : min(len(items), i + batch_size)]

    # Extract required information for upsert
    ids = [b["id"] for b in batch]
    transcripts = [b["Transcript"] for b in batch]
    embeddings = [b["embeddings"] for b in batch]
    metadata = [
        {
            "Author": b["Author"],
            "title": b["title"],
            "url": b["url"],
            "Transcript": b["Transcript"],
            "Type": b["Type"],
            "Publish_Date": b["Publish_Date"]
        }
        for b in batch
    ]

    # Upsert into index in batches
    vectors = [
        {
            "id": idx,
            "values": emb,
            "metadata": meta
        }
        for idx, emb, meta in zip(ids, embeddings, metadata)
    ]
    index.upsert(vectors=vectors)

# %% [markdown]
# # Using Cohere Embeddings

# %%
import time
from tqdm import tqdm
from openai import OpenAI
# from llama_index.embeddings.together import TogetherEmbedding
import cohere

co = cohere.Client("KQdbQsPZAxTEiBYFBmHnaubbLpdP9oqmg8OZmp0O")

new_df.reset_index(drop=True, inplace=True)

# Define a function to embed text with sleep after each call
def embed_text(text):
    # result = client.embeddings.create(input=text, model=EMBEDDING_ENGINE).data[0].embedding
    result = co.embed(texts=[text], model="embed-english-v3.0", input_type="search_document")
    time.sleep(0.2)  # Sleep for 5 seconds after each API call
    return result

# Initialize an empty list to store embeddings
embeddings = []

# Apply the function to each element of the DataFrame with tqdm progress bar
for index, row in tqdm(new_df.iterrows(), total=new_df.shape[0], desc="Embedding texts"):
    embedding = embed_text(row['Transcript'])
    embeddings.append(embedding)

# Assign the computed embeddings back to the DataFrame
new_df['embeddings'] = embeddings
# Out:
# Embedding texts:  10%|▉         | 170/1746 [01:44<16:06,  1.63it/s]
# ---------------------------------------------------------------------------
# TooManyRequestsError                      Traceback (most recent call last)
# Cell In[53], line 23
#      21 # Apply the function to each element of the DataFrame with tqdm progress bar
#      22 for index, row in tqdm(new_df.iterrows(), total=new_df.shape[0], desc="Embedding texts"):
# ---> 23     embedding = embed_text(row['Transcript'])
#      24     embeddings.append(embedding)
#      26 # Assign the computed embeddings back to the DataFrame
#
# Cell In[53], line 14, in embed_text(text)
#      12 def embed_text(text):
#      13     # result = client.embeddings.create(input=text, model=EMBEDDING_ENGINE).data[0].embedding
# ---> 14     result = co.embed(texts=[text], model="embed-english-v3.0", input_type="search_document")
#      15     time.sleep(0.2)  # Sleep for 5 seconds after each API call
#      16     return result
#
# File ~/Desktop/rag_project2/rag_project/my_virtual_env/lib/python3.10/site-packages/cohere/client.py:137, in Client.embed(self, texts, model, input_type, embedding_types, truncate, request_options, batching)
#     125     return BaseCohere.embed(
#     126         self,
#     127         texts=texts,
#    (...)
#     132         request_options=request_options,
#     133     )
#     135 texts_batches = [texts[i : i + embed_batch_size] for i in range(0, len(texts), embed_batch_size)]
# --> 137 responses = [
#     138     response
#     139     for response in self._executor.map(
#     140         lambda text_batch: BaseCohere.embed(
#     141             self,
#     142             texts=text_batch,
#     143             model=model,
#     144             input_type=input_type,
#     145             embedding_types=embedding_types,
#     146             truncate=truncate,
#     147             request_options=request_options,
#     148         ),
#     149         texts_batches,
#     150     )
#     151 ]
#     153 return merge_embed_responses(responses)
#
# File ~/Desktop/rag_project2/rag_project/my_virtual_env/lib/python3.10/site-packages/cohere/client.py:137, in <listcomp>(.0)
#     125     return BaseCohere.embed(
#     126         self,
#     127         texts=texts,
#    (...)
#     132         request_options=request_options,
#     133     )
#     135 texts_batches = [texts[i : i + embed_batch_size] for i in range(0, len(texts), embed_batch_size)]
# --> 137 responses = [
#     138     response
#     139     for response in self._executor.map(
#     140         lambda text_batch: BaseCohere.embed(
#     141             self,
#     142             texts=text_batch,
#     143             model=model,
#     144             input_type=input_type,
#     145             embedding_types=embedding_types,
#     146             truncate=truncate,
#     147             request_options=request_options,
#     148         ),
#     149         texts_batches,
#     150     )
#     151 ]
#     153 return merge_embed_responses(responses)
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:621, in Executor.map.<locals>.result_iterator()
#     618 while fs:
#     619     # Careful not to keep a reference to the popped future
#     620     if timeout is None:
# --> 621         yield _result_or_cancel(fs.pop())
#     622     else:
#     623         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     317 try:
#     318     try:
# --> 319         return fut.result(timeout)
#     320     finally:
#     321         fut.cancel()
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /usr/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/Desktop/rag_project2/rag_project/my_virtual_env/lib/python3.10/site-packages/cohere/client.py:140, in Client.embed.<locals>.<lambda>(text_batch)
#     125     return BaseCohere.embed(
#     126         self,
#     127         texts=texts,
#    (...)
#     132         request_options=request_options,
#     133     )
#     135 texts_batches = [texts[i : i + embed_batch_size] for i in range(0, len(texts), embed_batch_size)]
#     137 responses = [
#     138     response
#     139     for response in self._executor.map(
# --> 140         lambda text_batch: BaseCohere.embed(
#     141             self,
#     142             texts=text_batch,
#     143             model=model,
#     144             input_type=input_type,
#     145             embedding_types=embedding_types,
#     146             truncate=truncate,
#     147             request_options=request_options,
#     148         ),
#     149         texts_batches,
#     150     )
#     151 ]
#     153 return merge_embed_responses(responses)
#
# File ~/Desktop/rag_project2/rag_project/my_virtual_env/lib/python3.10/site-packages/cohere/base_client.py:1119, in BaseCohere.embed(self, texts, model, input_type, embedding_types, truncate, request_options)
#    1115     raise BadRequestError(
#    1116         typing.cast(typing.Any, construct_type(type_=typing.Any, object_=_response.json()))  # type: ignore
#    1117     )
#    1118 if _response.status_code == 429:
# -> 1119     raise TooManyRequestsError(
#    1120         typing.cast(typing.Any, construct_type(type_=typing.Any, object_=_response.json()))  # type: ignore
#    1121     )
#    1122 if _response.status_code == 500:
#    1123     raise InternalServerError(
#    1124         typing.cast(typing.Any, construct_type(type_=typing.Any, object_=_response.json()))  # type: ignore
#    1125     )
#
# TooManyRequestsError: status_code: 429, body: {'message': "You are using a Trial key, which is limited to 100 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
